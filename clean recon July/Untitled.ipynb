# %%
# %load_ext autoreload
# %autoreload 2

# %%
! rm -r  /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Aug24_131/

# %%
! mkdir /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Aug24_131/

# %%
# %run itorch_hole_longt 0.4 0
# Out:
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127

# %%
# %run itorch_half0 1.0 0
# Out:
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Aug10_112_half0/pytorchrecon_6_Up1.0_seed1.npy exists
# one done
# one done
# one done
# one done
# /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Aug10_112_half0/pytorchrecon_7_Up1.0_seed1.npy exists
# one done
# one done
# /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Aug10_112_half0/pytorchrecon_7_Up1.0_seed4.npy exists
# one done
# one done
# one done
# /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Aug10_112_half0/pytorchrecon_8_Up1.0_seed3.npy exists
# one done
# one done
# one done
# one done
# ...

# %%
# %run itorch_hole_longt 1.0 0

# %%
# %run itorch_hole_longt 0.7
# Out:
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# ...
