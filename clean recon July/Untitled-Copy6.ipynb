# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %run itorch_hole_longt 0.7 0
# Out:
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# ...

# %%
# %run itorch_half0 0.7 0
# Out:
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# ...

# %%
# %run itorch_hole_longt 0.2 0
