# %%
# %load_ext autoreload
# %autoreload 2

# %%
! mkdir /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul13_127

# %%
# %run itorch_hole_longt 0.7
# Out:
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim
# one done, eshift 1 for exp, 0 for sim

# %%
# %run itorch_hole_longt 0.9
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/cVMI/clean recon July/itorch_hole_longt.py in <module>
#     130 Up = Ups[0]
#     131 filename = 'Bpbasis_Np' + str(Np) + '_Nw' + str(N_w) +'_Nt' + str(N_t) + '_Up' + str(Up)+'.npy'
# --> 132 br = np.load(basesdir+filename, allow_pickle=True)
#     133 Breal = br[()]['Breal']
#     134 Bimag = br[()]['Bimag']
#
# /reg/g/psdm/sw/conda/inst/miniconda2-prod-rhel7/envs/deeplearning3/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     451             else:
#     452                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 453                                          pickle_kwargs=pickle_kwargs)
#     454         else:
#     455             # Try a pickle
#
# /reg/g/psdm/sw/conda/inst/miniconda2-prod-rhel7/envs/deeplearning3/lib/python3.7/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     742             pickle_kwargs = {}
#     743         try:
# --> 744             array = pickle.load(fp, **pickle_kwargs)
#     745         except UnicodeError as err:
#     746             if sys.version_info[0] >= 3:
#
# KeyboardInterrupt:
