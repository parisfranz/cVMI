# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %run itorch_hole_longt 0.4 -1
# Out:
# /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Aug24_131/pytorchrecon_40_Up0.4_seed0.npy exists
# /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Aug24_131/pytorchrecon_40_Up0.4_seed1.npy exists
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127

# %%
# %run itorch_half0 0 0
# Out:
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# ...

# %%
# %run itorch_hole_longt 1.0 -1

# %%
# %run itorch_hole_longt 0.05
# Out:
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# ...
