# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %run itorch_hole_longt 0.9 0
# Out:
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# one done, new indexes for run 127
# ...

# %%
# %run itorch_half0 0.9 0
# Out:
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# one done
# ...

# %%
# %run itorch_hole_longt 0.4 0
