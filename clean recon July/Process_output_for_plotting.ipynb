# %%
#process the pytorch fitting outfit into single large data files with calcs for plotting

# %%
2.5/1.8
# Out:
# 1.3888888888888888

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from __future__ import print_function
import numpy as np
#from tqdm import tqdm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
from matplotlib import cm
plt.rcParams.update({'font.size': 14, 'lines.markersize' : 4})
from scipy.interpolate import interp1d
from scipy.optimize import curve_fit
import sys, os
import time, datetime
from datetime import timedelta
import pandas as pd
sys.path.append('/reg/neh/home/tdd14/modules/cart2pol/cart2pol')
import cart2pol
from cart2pol import PolarRebin
from torchrecon_funcs_cal import *

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap
my_cmap = cm.get_cmap('jet')
xr = np.linspace(0, 1, 2000)
my_cmap = my_cmap(xr)
my_cmap[0:2,-1] = 0
my_cmap = ListedColormap(my_cmap)

# %%
#basesdir = '/reg/d/psdm/tmo/tmox51020/results/paris/circularpol_vNbases_dipole_K5/'
basesdir = '/reg/d/psdm/tmo/tmox51020/results/paris/circularpol_vNbases_dipole_Feb/'
PR = PolarRebin('/reg/d/psdm/tmo/tmox51020/results/paris/recon/PR_c32_r32_th32.h5')

# %%
! du -h --max-depth=1 /reg/d/psdm/tmo/tmox51020/results/paris/recon/
# Out:
# 48K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/dp_bg_7Oct_K5_gf10_cal40_6
# 151K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jun15_unstreaked_dw0
# 89K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul26_127
# 76K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/dp_bg_4Oct_K5_gf10_cal_6
# 55K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/dp_bg_10Oct_K5_gf10_smoothphase_N
# 69K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/dp_bg_1Oct_K5_gf10_cal
# 55K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/dp_bg_10Oct_K5_32_smoothphase
# 96K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul21_127
# 230K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar14_121
# 388K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/thresh_inbg_run112
# 60K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar7_0-1eV
# 32K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan6_hole_noQ_spec_half
# 937K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/dp_bg_11Oct_K5_gf10_smoothphase_N
# ...

# %%
! find /reg/d/psdm/tmo/tmox51020/results/paris/recon/ -type f | wc -l
# Out:
# 3841

# %%
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan4_hole_noQ_cal_nospec'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan5_hole_noQ_cal_hspec'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan6_hole_noQ_spec_half'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan9_hole_noQ_cal_spec_eshift'
# basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan11_hole_noQ_spec_half'
# basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan16_hole_noQ_cal_spec_eshift/'
#basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan19_hole_noQ_cal_spec_eshift_2/'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan19_niceseed/'
#basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan12_cal/'
#basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan9_hole_noQ_cal_spec_eshift/'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan8_hole_noQ_cal_spec'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Feb1_116/'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Feb2_117'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Feb3_110'
#_______ new bases
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Feb20_112/'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar2_112'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar3_112_bighole'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar3_112'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar6_112-1eV'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar9_112'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar10_110'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar12_112'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar13_121'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar14_121'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar16_122'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar17_123'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar19_124'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar20_123'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar25_127/'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar23_125'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar28_112'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_May31_127'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul13_127'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul14_127'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul17_112'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul18_127'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul18_127_2'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul18_127_3'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul20_127'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul20_127_2'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul21_127'
#basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul21_127_2'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul23_112'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul24_112'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul26_127'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul26_127_2'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul26_127_3'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul26_127_4'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul26_127_5'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul27_127'
basedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul27_112'
files = np.array(os.listdir(basedir))
files = files[np.array(['.npy' in file for file in files])]
#files = sorted(files, key=lambda f: float(f.split('run')[0]))
print(len(files))
files
# Out:
# 680
# array(['pytorchrecon_195_Up0.6_seed4.npy',
#        'pytorchrecon_191_Up0.7_seed1.npy',
#        'pytorchrecon_171_Up0.1_seed2.npy',
#        'pytorchrecon_139_Up0.3_seed0.npy',
#        'pytorchrecon_177_Up0.0_seed1.npy',
#        'pytorchrecon_184_Up0.1_seed3.npy',
#        'pytorchrecon_202_Up0.4_seed1.npy',
#        'pytorchrecon_33_Up0.1_seed3.npy',
#        'pytorchrecon_194_Up0.3_seed4.npy',
#        'pytorchrecon_114_Up0.1_seed1.npy',
#        'pytorchrecon_121_Up0.2_seed4.npy',
#        'pytorchrecon_184_Up0.1_seed4.npy',
#        'pytorchrecon_169_Up0.0_seed1.npy',
#        'pytorchrecon_102_Up0.2_seed2.npy',
#        'pytorchrecon_33_Up0.1_seed4.npy',
#        'pytorchrecon_127_Up0.3_seed0.npy',
#        'pytorchrecon_194_Up0.3_seed3.npy',
#        'pytorchrecon_191_Up1.0_seed2.npy',
#        'pytorchrecon_121_Up0.2_seed3.npy',
#        'pytorchrecon_195_Up0.6_seed3.npy',
#        'pytorchrecon_175_Up0.0_seed0.npy',
#        'pytorchrecon_129_Up0.1_seed0.npy',
# ...

# %%
l = 13
dat = np.ndarray(len(files), dtype = [('seed', int),('ID', int),('Up', float), ('Qs', float, 2*36-1),\
                                      ('costs', float,l), ('costM', float,l), ('costW', float,l), ('costS', float,l),\
                                      ('costQ', float, l), ('eshift',float), ('M_wght', float), ('Spec_wght', float),\
                                      ('Smooth_wght', float),\
                                      ('costMn', float,l), ('costWn', float,l), ('costSn', float,l),\
                                      ('Etvar', float),\
                                           ])

# %%
for i,f in enumerate(files):
    test = np.load(os.path.join(basedir,f), allow_pickle=True).item()
    for n in dat.dtype.names[:]:
        try:
            dat[i][n]=test[n]
        except:
            if n == 'costMn':
                try:
                    dat[i][n]=np.array(test['costM'])/test['M_wght']
                except:
                    dat[i][n] = 0
            elif n == 'costWn':
                try:
                    dat[i][n]=np.array(test['costW'])/test['Spec_wght']
                except:
                    dat[i][n] = 0
            elif n == 'costSn':
                try:
                    dat[i][n]=np.array(test['costS'])/test['Smooth_wght']
                except:
                    dat[i][n] = 0 
                
            elif n == 'Etvar':
                continue
            else: print(n)

# %%
for i,j in enumerate(np.unique(dat['ID'])):
    print('ID %1.0f, # files %1.0f' %(j,len(dat[dat['ID'] == j])))
# Out:
# ID 33, # files 40
# ID 102, # files 40
# ID 114, # files 40
# ID 121, # files 40
# ID 127, # files 40
# ID 129, # files 40
# ID 139, # files 40
# ID 155, # files 40
# ID 169, # files 40
# ID 171, # files 40
# ID 175, # files 40
# ID 177, # files 40
# ID 184, # files 40
# ID 191, # files 40
# ID 194, # files 40
# ID 195, # files 40
# ID 202, # files 40

# %%
Ups = np.unique(dat['Up'])
Ups
# Out:
# array([0. , 0.1, 0.2, 0.3, 0.4, 0.6, 0.7, 1. ])

# %%
mfn = test['mfn'] #int(sys.argv[5]) #applied to the measured image for preprocessing
gfn = test['gfn'] #float(sys.argv[6])
gfsig = test['gfsig'] #0.985 #0.985 #0.875
eshift = test['eshift']
thresh = test['thresh']
M_wght = test['M_wght']
Spec_wght= test['Spec_wght'] 
Smooth_wght = test['Smooth_wght'] 
print(mfn,gfn,gfsig, eshift)
print(thresh)
runnum = 121 #int(sys.argv[7])
gfcart = 0.25 #applied to the simulated image to try to make it match the measured
mfcart = 1
#thresh = 0.00032 #0.00037
# Out:
# 0 0 0.985 0
# 0.0006

# %%
# Bps = []
# alphas = []
# vNaxiss = []
# alphaws = []
# N_w = 6
# N_t = 6
# Nb = N_w*N_t
# for i in range(len(Ups)):
#     Np = 128
#     Up = Ups[i]  
#     filename = 'Bpbasis_Np' + str(Np) + '_Nw' + str(N_w) +'_Nt' + str(N_t) + '_Up' + str(Up)+'.npy'
#     print(filename)
#     br = np.load(basesdir+filename, allow_pickle=True)
#     Breal = br[()]['Breal']
#     Bimag = br[()]['Bimag']
#     breal = br[()]['breal']
#     bimag = br[()]['bimag']
#     vNaxis = br[()]['vNaxis']
#     alpha = br[()]['alpha']

    
#     tempr = np.zeros((Breal.shape[0], 64**2))
#     tempi = np.zeros((Breal.shape[0], 64**2))
#     for i in range(len(Breal)):
#         tempr[i,:] = np.reshape(rebin(np.reshape(Breal[i,:], [128,128])), [64**2])
#         tempi[i,:] = np.reshape(rebin(np.reshape(Bimag[i,:], [128,128])), [64**2])

#     Breal = tempr
#     Bimag = tempi

#     alphw = np.zeros(alpha['t_sample'].shape, dtype = complex)
#     for i in range(len(alphw)):
#         alphw[i] = np.fft.ifftshift(np.fft.ifft(alpha['t_sample'][i]))

#     Np = 64
#     for j in range(Breal.shape[0]):
#         temp=np.reshape(Breal[j,:],[Np,Np])
#         polimg = PR.cart2pol(temp,32,32)
#         bb = np.zeros((64,64))
#         bb[1:64,1:64]= PR.pol2cart(scimg.filters.gaussian_filter(polimg,[gfsig,0]))
#         Breal[j,:]=np.reshape(bb,newshape=(1,Np**2))
#         #temp=scimg.filters.gaussian_filter(temp,0.8889)
#         #Bpr[j,:]=Variable(Tensor(np.reshape(temp,newshape=(1,Np**2))))
#         temp=np.reshape(Bimag[j,:],[Np,Np])
#         polimg = PR.cart2pol(temp,32,32)
#         bb = np.zeros((64,64))
#         bb[1:64,1:64]= PR.pol2cart(scimg.filters.gaussian_filter(polimg,[gfsig,0]))
#         Bimag[j,:]=np.reshape(bb,newshape=(1,Np**2))
#         #temp=scimg.filters.gaussian_filter(temp,0.8889)
#         #Bpi[j,:]=Variable(Tensor(np.reshape(temp,newshape=(1,Np**2))))

#     Bp_basis = Breal+1j*Bimag

#     Bps.append(Bp_basis)
#     alphas.append(alpha)
#     vNaxiss.append(vNaxis)
#     alphaws.append(alphw)

# %%
# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Jan19_110_2.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Jan19_110_2.npy'
# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Jan19_110.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Jan19_110.npy'
#mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Jan11.npy'
#specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Jan11.npy'
# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Dec16.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Dec16.npy'
# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Mar9_112.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Mar9_112.npy'
# thresh = 0.00032 #0.00037
# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Mar10_110.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Mar10_110.npy'
# thresh = 0.00032 #0.00037
# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Mar12_112.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Mar12_112.npy'
# thresh = test['thresh']
# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Mar14_121.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Mar14_121.npy'
# thresh = test['thresh']
# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Mar16_122.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Mar16_122.npy'
# thresh = test['thresh']
# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Mar17_123.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Mar17_123.npy'
# thresh = test['thresh']
# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Mar19_124.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Mar19_124.npy'
# thresh = test['thresh']
# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Mar20_123.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Mar20_123.npy'
# thresh = test['thresh']
# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Mar25_127.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Mar25_127.npy'
# thresh = test['thresh']

mdatname = test['mdatname'] 
specdatname = test['specdatname']
thresh = test['thresh']
print(mdatname,specdatname,thresh)


# mdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Mar23_125.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Mar23_125.npy'
# thresh = test['thresh']

# mdatname= '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Feb1_116.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Feb1_116.npy'
#mdatname= '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Feb2_117.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Feb2_117.npy'
# mdatname= '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Feb3_110.npy'
# specdatname = '/cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Feb3_110.npy'
# Out:
# /cds/home/p/paris/reconVMI_clean/recon X510 Dec/Ms_Jul27_112.npy /cds/home/p/paris/reconVMI_clean/recon X510 Dec/specs_Jul27_112.npy 0.0006

# %%
# for i in range(len(dat)):
#     temp = []
#     uplook = dat[i]['Up']
#     ID = dat[i]['ID']
#     try:
#         u = int(np.where(Ups == uplook)[0])
#         m = dat[i]['M_wght']
#         w = dat[i]['Spec_wght']
#         sm = dat[i]['Smooth_wght']
#         Bp = Bps[u]
#         vNaxis = vNaxiss[u]
#         alpha = alphas[u]
#         ts=vNaxis['t_sample']
    
#         dat0 = dat[(dat['ID'] == ID)&(dat['Up'] == uplook)&(dat['M_wght'] == m)&(dat['Spec_wght'] == w)&(dat['Smooth_wght'] == sm)]
#         for j in range(3):
#             try:
#                 Q = np.squeeze(dat0[j]['Qs'])
#                 N_basis = 36
#                 Q1=Q[0:N_basis]
#                 Q1=np.reshape(Q1,[1,N_basis])
#                 Q2=np.concatenate(([0],Q[N_basis:2*N_basis-1]))
#                 Q2=np.reshape(Q2,[1,N_basis])
#                 Qguess=Q1+1j*Q2
#                 Qguess=np.reshape(Qguess,[N_basis,1])
#                 # Mgr=np.real(np.matmul(np.matmul(Qguess,Qguess.conj().transpose()).transpose().flatten(),Bp))
#                 # Mgr=Mgr/np.sum(Mgr)
#                 # Mgr[Mgr<0.0005] = 0
#                 # Mgr=Mgr/np.sum(Mgr)

#                 alpha_t = alpha['t_sample']/np.max(np.abs(alpha['t_sample'])) ##take out carrier
#                 Et = np.squeeze(np.matmul(Qguess.T,alpha_t))
#                 EtEt= np.squeeze(Et*Et.conj())
#                 EtEt = EtEt/np.max(EtEt)
#                 temp.append(EtEt)
#             except:
#                 continue
                
                
#     except:
#         continue
#     temp = np.array(temp)
#     dat[i]['Etvar'] = np.sum(np.var(temp,axis = 0))

# %%
# X,Y=np.meshgrid(np.arange(1024),np.arange(1024))
# rs=np.sqrt((X-512)**2+(Y-512)**2)
# maskhm=np.zeros((1024,1024))
# maskhm[(rs>325-30) & (rs<420)]=1
# #maskhm[(rs>325-42/2) & (rs<430+42/2)]=1 #12 eV around where unstreaked photoline is
# #maskhm[(rs>318) & (rs<430+42/2)]=1
# mask = rebin(rebin(maskhm,4),4)
mask = test['mask']

# %%
dats = {'dat': dat, 'mask': mask, 'mdatname': mdatname, 'specdatname': specdatname,\
        'gfsig':gfsig, 'eshift':eshift, 'sc': test['sc'],'thresh': thresh, 'M_wght': M_wght, 'Spec_wght': Spec_wght,\
        'Smooth_wght': Smooth_wght }

# %%
fname = basedir.split('recon/')[1].split('/')[0]
fname = fname + '.npy'
print(fname)
# Out:
# torch_Jul27_112.npy

# %%
savedir = '/reg/d/psdm/tmo/tmox51020/results/paris/recon' #save in recon folder (one up)
print(os.path.join(savedir,fname))
# Out:
# /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul27_112.npy

# %%
np.save(os.path.join(savedir,fname),dats)

# %%
basedir
# Out:
# '/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul26_127_4'

# %%
! rm -r /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul27_127/*.npy

# %%
! ls /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Feb3_110.npy
# Out:
# /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Feb3_110.npy

# %%
! find /reg/d/psdm/tmo/tmox51020/results/paris/recon/ -type f | wc -l
# Out:
# 2638

# %%
rm -r /reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Feb22_0

# %%
! du -h --max-depth=1 /reg/d/psdm/tmo/tmox51020/results/paris/recon #/torch_Feb*
# Out:
# 48K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/dp_bg_7Oct_K5_gf10_cal40_6
# 151K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jun15_unstreaked_dw0
# 89K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul26_127
# 76K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/dp_bg_4Oct_K5_gf10_cal_6
# 55K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/dp_bg_10Oct_K5_gf10_smoothphase_N
# 69K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/dp_bg_1Oct_K5_gf10_cal
# 55K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/dp_bg_10Oct_K5_32_smoothphase
# 96K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jul21_127
# 230K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar14_121
# 388K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/thresh_inbg_run112
# 60K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Mar7_0-1eV
# 32K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/torch_Jan6_hole_noQ_spec_half
# 937K	/reg/d/psdm/tmo/tmox51020/results/paris/recon/dp_bg_11Oct_K5_gf10_smoothphase_N
# ...
